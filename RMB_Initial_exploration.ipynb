# %% [markdown]
# # Aim:
# Initial exploration of the datasets. See what is available and what shape they are in
#
# Dataset source : https://data.gov.ie/dataset/dublinbikes-api

# %%
import requests
import urllib.parse
import pandas as pd

# %% [markdown]
# ## Get latest snapshot of data (near real-time)

# %%
snapshot_api_url = "https://data.smartdublin.ie/dublinbikes-api/last_snapshot/"

# %%
# Send off request for data
snapshot_response = requests.get(snapshot_api_url)
snapshot_response.json()
# Out:
# [{'id': 46911573,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 2,
#   'available_bike_stands': 11,
#   'bike_stands': 20,
#   'available_bikes': 9,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:15:19',
#   'status': 'OPEN',
#   'address': 'Blessington Street',
#   'name': 'BLESSINGTON STREET',
#   'latitude': '53.3568',
#   'longitude': '-6.26814'},
#  {'id': 46911593,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 3,
#   'available_bike_stands': 7,
#   'bike_stands': 20,
#   'available_bikes': 13,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:02',
#   'status': 'OPEN',
#   'address': 'Bolton Street',
#   'name': 'BOLTON STREET',
#   'latitude': '53.3512',
#   'longitude': '-6.26986'},
#  {'id': 46911534,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 4,
#   'available_bike_stands': 16,
#   'bike_stands': 20,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:11:07',
#   'status': 'OPEN',
#   'address': 'Greek Street',
#   'name': 'GREEK STREET',
#   'latitude': '53.3469',
#   'longitude': '-6.27298'},
#  {'id': 46911529,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 5,
#   'available_bike_stands': 21,
#   'bike_stands': 40,
#   'available_bikes': 19,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:19:04',
#   'status': 'OPEN',
#   'address': 'Charlemont Street',
#   'name': 'CHARLEMONT PLACE',
#   'latitude': '53.3307',
#   'longitude': '-6.26018'},
#  {'id': 46911498,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 6,
#   'available_bike_stands': 11,
#   'bike_stands': 20,
#   'available_bikes': 9,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:01',
#   'status': 'OPEN',
#   'address': 'Christchurch Place',
#   'name': 'CHRISTCHURCH PLACE',
#   'latitude': '53.3434',
#   'longitude': '-6.27012'},
#  {'id': 46911537,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 7,
#   'available_bike_stands': 21,
#   'bike_stands': 29,
#   'available_bikes': 7,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:26',
#   'status': 'OPEN',
#   'address': 'High Street',
#   'name': 'HIGH STREET',
#   'latitude': '53.3436',
#   'longitude': '-6.27507'},
#  {'id': 46911549,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 8,
#   'available_bike_stands': 10,
#   'bike_stands': 30,
#   'available_bikes': 20,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:50',
#   'status': 'OPEN',
#   'address': 'Custom House Quay',
#   'name': 'CUSTOM HOUSE QUAY',
#   'latitude': '53.3479',
#   'longitude': '-6.24805'},
#  {'id': 46911524,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 9,
#   'available_bike_stands': 6,
#   'bike_stands': 24,
#   'available_bikes': 18,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:39',
#   'status': 'OPEN',
#   'address': 'Exchequer Street',
#   'name': 'EXCHEQUER STREET',
#   'latitude': '53.343',
#   'longitude': '-6.26358'},
#  {'id': 46911580,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 10,
#   'available_bike_stands': 1,
#   'bike_stands': 16,
#   'available_bikes': 14,
#   'banking': True,
#   'bonus': False,
#   'last_update': '2022-03-01T18:13:40',
#   'status': 'OPEN',
#   'address': 'Dame Street',
#   'name': 'DAME STREET',
#   'latitude': '53.344',
#   'longitude': '-6.2668'},
#  {'id': 46911515,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 11,
#   'available_bike_stands': 27,
#   'bike_stands': 30,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:55',
#   'status': 'OPEN',
#   'address': 'Earlsfort Terrace',
#   'name': 'EARLSFORT TERRACE',
#   'latitude': '53.3343',
#   'longitude': '-6.2585'},
#  {'id': 46911570,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 12,
#   'available_bike_stands': 13,
#   'bike_stands': 20,
#   'available_bikes': 7,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:03',
#   'status': 'OPEN',
#   'address': 'Eccles Street',
#   'name': 'ECCLES STREET',
#   'latitude': '53.3592',
#   'longitude': '-6.26978'},
#  {'id': 46911503,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 13,
#   'available_bike_stands': 13,
#   'bike_stands': 30,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:55',
#   'status': 'OPEN',
#   'address': 'Fitzwilliam Square West',
#   'name': 'FITZWILLIAM SQUARE WEST',
#   'latitude': '53.3361',
#   'longitude': '-6.25282'},
#  {'id': 46911578,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 15,
#   'available_bike_stands': 16,
#   'bike_stands': 16,
#   'available_bikes': 0,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:00',
#   'status': 'OPEN',
#   'address': 'Hardwicke Street',
#   'name': 'HARDWICKE STREET',
#   'latitude': '53.3555',
#   'longitude': '-6.26442'},
#  {'id': 46911551,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 16,
#   'available_bike_stands': 0,
#   'bike_stands': 20,
#   'available_bikes': 20,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:06',
#   'status': 'OPEN',
#   'address': 'Georges Quay',
#   'name': 'GEORGES QUAY',
#   'latitude': '53.3475',
#   'longitude': '-6.25219'},
#  {'id': 46911516,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 17,
#   'available_bike_stands': 16,
#   'bike_stands': 20,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:36',
#   'status': 'OPEN',
#   'address': 'Golden Lane',
#   'name': 'GOLDEN LANE',
#   'latitude': '53.3408',
#   'longitude': '-6.26773'},
#  {'id': 46911499,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 18,
#   'available_bike_stands': 14,
#   'bike_stands': 30,
#   'available_bikes': 16,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:07',
#   'status': 'OPEN',
#   'address': 'Grantham Street',
#   'name': 'GRANTHAM STREET',
#   'latitude': '53.3341',
#   'longitude': '-6.26544'},
#  {'id': 46911536,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 19,
#   'available_bike_stands': 26,
#   'bike_stands': 30,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:27',
#   'status': 'OPEN',
#   'address': 'Herbert Place',
#   'name': 'HERBERT PLACE',
#   'latitude': '53.3344',
#   'longitude': '-6.24557'},
#  {'id': 46911601,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 21,
#   'available_bike_stands': 7,
#   'bike_stands': 30,
#   'available_bikes': 23,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:36',
#   'status': 'OPEN',
#   'address': 'Leinster Street South',
#   'name': 'LEINSTER STREET SOUTH',
#   'latitude': '53.3422',
#   'longitude': '-6.25449'},
#  {'id': 46911567,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 22,
#   'available_bike_stands': 1,
#   'bike_stands': 20,
#   'available_bikes': 19,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:21',
#   'status': 'OPEN',
#   'address': 'Townsend Street',
#   'name': 'TOWNSEND STREET',
#   'latitude': '53.3459',
#   'longitude': '-6.25461'},
#  {'id': 46911507,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 23,
#   'available_bike_stands': 13,
#   'bike_stands': 30,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:55',
#   'status': 'OPEN',
#   'address': 'Custom House',
#   'name': 'CUSTOM HOUSE',
#   'latitude': '53.3483',
#   'longitude': '-6.25466'},
#  {'id': 46911582,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 24,
#   'available_bike_stands': 12,
#   'bike_stands': 20,
#   'available_bikes': 8,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:13:42',
#   'status': 'OPEN',
#   'address': 'Cathal Brugha Street',
#   'name': 'CATHAL BRUGHA STREET',
#   'latitude': '53.3521',
#   'longitude': '-6.26053'},
#  {'id': 46911558,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 25,
#   'available_bike_stands': 26,
#   'bike_stands': 30,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:43',
#   'status': 'OPEN',
#   'address': 'Merrion Square East',
#   'name': 'MERRION SQUARE EAST',
#   'latitude': '53.3394',
#   'longitude': '-6.24655'},
#  {'id': 46911576,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 26,
#   'available_bike_stands': 10,
#   'bike_stands': 20,
#   'available_bikes': 10,
#   'banking': True,
#   'bonus': False,
#   'last_update': '2022-03-01T18:10:08',
#   'status': 'OPEN',
#   'address': 'Merrion Square West',
#   'name': 'MERRION SQUARE WEST',
#   'latitude': '53.3398',
#   'longitude': '-6.25199'},
#  {'id': 46911550,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 27,
#   'available_bike_stands': 16,
#   'bike_stands': 20,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:13:52',
#   'status': 'OPEN',
#   'address': 'Molesworth Street',
#   'name': 'MOLESWORTH STREET',
#   'latitude': '53.3413',
#   'longitude': '-6.25812'},
#  {'id': 46911597,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 28,
#   'available_bike_stands': 22,
#   'bike_stands': 30,
#   'available_bikes': 8,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:12:15',
#   'status': 'OPEN',
#   'address': 'Mountjoy Square West',
#   'name': 'MOUNTJOY SQUARE WEST',
#   'latitude': '53.3563',
#   'longitude': '-6.25859'},
#  {'id': 46911595,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 29,
#   'available_bike_stands': 19,
#   'bike_stands': 29,
#   'available_bikes': 10,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:49',
#   'status': 'OPEN',
#   'address': 'Ormond Quay Upper',
#   'name': 'ORMOND QUAY UPPER',
#   'latitude': '53.3461',
#   'longitude': '-6.268'},
#  {'id': 46911494,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 30,
#   'available_bike_stands': 19,
#   'bike_stands': 20,
#   'available_bikes': 1,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:48',
#   'status': 'OPEN',
#   'address': 'Parnell Square North',
#   'name': 'PARNELL SQUARE NORTH',
#   'latitude': '53.3535',
#   'longitude': '-6.26531'},
#  {'id': 46911505,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 31,
#   'available_bike_stands': 9,
#   'bike_stands': 20,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:22',
#   'status': 'OPEN',
#   'address': 'Parnell Street',
#   'name': 'PARNELL STREET',
#   'latitude': '53.3509',
#   'longitude': '-6.26512'},
#  {'id': 46911500,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 32,
#   'available_bike_stands': 25,
#   'bike_stands': 30,
#   'available_bikes': 5,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:58',
#   'status': 'OPEN',
#   'address': 'Pearse Street',
#   'name': 'PEARSE STREET',
#   'latitude': '53.3443',
#   'longitude': '-6.25043'},
#  {'id': 46911587,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 33,
#   'available_bike_stands': 9,
#   'bike_stands': 23,
#   'available_bikes': 14,
#   'banking': True,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:27',
#   'status': 'OPEN',
#   'address': "Princes Street / O'Connell Street",
#   'name': "PRINCES STREET / O'CONNELL STREET",
#   'latitude': '53.349',
#   'longitude': '-6.26031'},
#  {'id': 46911571,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 34,
#   'available_bike_stands': 3,
#   'bike_stands': 30,
#   'available_bikes': 27,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:34',
#   'status': 'OPEN',
#   'address': 'Portobello Harbour',
#   'name': 'PORTOBELLO HARBOUR',
#   'latitude': '53.3304',
#   'longitude': '-6.26516'},
#  {'id': 46911565,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 36,
#   'available_bike_stands': 29,
#   'bike_stands': 40,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:11:45',
#   'status': 'OPEN',
#   'address': "St. Stephen's Green East",
#   'name': "ST. STEPHEN'S GREEN EAST",
#   'latitude': '53.3378',
#   'longitude': '-6.25603'},
#  {'id': 46911560,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 37,
#   'available_bike_stands': 20,
#   'bike_stands': 30,
#   'available_bikes': 10,
#   'banking': True,
#   'bonus': False,
#   'last_update': '2022-03-01T18:12:18',
#   'status': 'OPEN',
#   'address': "St. Stephen's Green South",
#   'name': "ST. STEPHEN'S GREEN SOUTH",
#   'latitude': '53.3375',
#   'longitude': '-6.26199'},
#  {'id': 46911540,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 38,
#   'available_bike_stands': 1,
#   'bike_stands': 40,
#   'available_bikes': 39,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:49',
#   'status': 'OPEN',
#   'address': 'Talbot Street',
#   'name': 'TALBOT STREET',
#   'latitude': '53.351',
#   'longitude': '-6.25294'},
#  {'id': 46911598,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 39,
#   'available_bike_stands': 20,
#   'bike_stands': 20,
#   'available_bikes': 0,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:26',
#   'status': 'OPEN',
#   'address': 'Wilton Terrace',
#   'name': 'WILTON TERRACE',
#   'latitude': '53.3324',
#   'longitude': '-6.25272'},
#  {'id': 46911594,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 40,
#   'available_bike_stands': 15,
#   'bike_stands': 21,
#   'available_bikes': 6,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:22',
#   'status': 'OPEN',
#   'address': 'Jervis Street',
#   'name': 'JERVIS STREET',
#   'latitude': '53.3483',
#   'longitude': '-6.26665'},
#  {'id': 46911592,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 41,
#   'available_bike_stands': 19,
#   'bike_stands': 20,
#   'available_bikes': 1,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:20',
#   'status': 'OPEN',
#   'address': 'Harcourt Terrace',
#   'name': 'HARCOURT TERRACE',
#   'latitude': '53.3328',
#   'longitude': '-6.25794'},
#  {'id': 46911493,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 42,
#   'available_bike_stands': 9,
#   'bike_stands': 30,
#   'available_bikes': 21,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:25',
#   'status': 'OPEN',
#   'address': 'Smithfield North',
#   'name': 'SMITHFIELD NORTH',
#   'latitude': '53.3496',
#   'longitude': '-6.2782'},
#  {'id': 46911504,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 43,
#   'available_bike_stands': 1,
#   'bike_stands': 30,
#   'available_bikes': 29,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:15:04',
#   'status': 'OPEN',
#   'address': 'Portobello Road',
#   'name': 'PORTOBELLO ROAD',
#   'latitude': '53.3301',
#   'longitude': '-6.26804'},
#  {'id': 46911588,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 44,
#   'available_bike_stands': 19,
#   'bike_stands': 30,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:11:31',
#   'status': 'OPEN',
#   'address': 'Upper Sherrard Street',
#   'name': 'UPPER SHERRARD STREET',
#   'latitude': '53.3584',
#   'longitude': '-6.26064'},
#  {'id': 46911517,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 45,
#   'available_bike_stands': 6,
#   'bike_stands': 30,
#   'available_bikes': 24,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:13:42',
#   'status': 'OPEN',
#   'address': 'Deverell Place',
#   'name': 'DEVERELL PLACE',
#   'latitude': '53.3515',
#   'longitude': '-6.25527'},
#  {'id': 46911547,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 47,
#   'available_bike_stands': 40,
#   'bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:12:52',
#   'status': 'OPEN',
#   'address': 'Herbert Street',
#   'name': 'HERBERT STREET',
#   'latitude': '53.3357',
#   'longitude': '-6.24551'},
#  {'id': 46911502,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 48,
#   'available_bike_stands': 14,
#   'bike_stands': 40,
#   'available_bikes': 26,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:31',
#   'status': 'OPEN',
#   'address': 'Excise Walk',
#   'name': 'EXCISE WALK',
#   'latitude': '53.3478',
#   'longitude': '-6.24424'},
#  {'id': 46911535,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 49,
#   'available_bike_stands': 18,
#   'bike_stands': 40,
#   'available_bikes': 21,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:10',
#   'status': 'OPEN',
#   'address': 'Guild Street',
#   'name': 'GUILD STREET',
#   'latitude': '53.3479',
#   'longitude': '-6.24093'},
#  {'id': 46911568,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 50,
#   'available_bike_stands': 21,
#   'bike_stands': 40,
#   'available_bikes': 19,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:44',
#   'status': 'OPEN',
#   'address': "George's Lane",
#   'name': 'GEORGES LANE',
#   'latitude': '53.3502',
#   'longitude': '-6.2797'},
#  {'id': 46911559,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 51,
#   'available_bike_stands': 25,
#   'bike_stands': 40,
#   'available_bikes': 15,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:00',
#   'status': 'OPEN',
#   'address': 'York Street West',
#   'name': 'YORK STREET WEST',
#   'latitude': '53.3393',
#   'longitude': '-6.2647'},
#  {'id': 46911501,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 52,
#   'available_bike_stands': 27,
#   'bike_stands': 32,
#   'available_bikes': 5,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:12',
#   'status': 'OPEN',
#   'address': 'York Street East',
#   'name': 'YORK STREET EAST',
#   'latitude': '53.3388',
#   'longitude': '-6.262'},
#  {'id': 46911541,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 53,
#   'available_bike_stands': 33,
#   'bike_stands': 40,
#   'available_bikes': 7,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:13:56',
#   'status': 'OPEN',
#   'address': 'Newman House',
#   'name': 'NEWMAN HOUSE',
#   'latitude': '53.3371',
#   'longitude': '-6.26059'},
#  {'id': 46911495,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 54,
#   'available_bike_stands': 29,
#   'bike_stands': 33,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:15:56',
#   'status': 'OPEN',
#   'address': 'Clonmel Street',
#   'name': 'CLONMEL STREET',
#   'latitude': '53.336',
#   'longitude': '-6.26298'},
#  {'id': 46911527,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 55,
#   'available_bike_stands': 34,
#   'bike_stands': 36,
#   'available_bikes': 2,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:14:37',
#   'status': 'OPEN',
#   'address': 'Hatch Street',
#   'name': 'HATCH STREET',
#   'latitude': '53.334',
#   'longitude': '-6.26071'},
#  {'id': 46911497,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 56,
#   'available_bike_stands': 19,
#   'bike_stands': 40,
#   'available_bikes': 21,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:57',
#   'status': 'OPEN',
#   'address': 'Mount Street Lower',
#   'name': 'MOUNT STREET LOWER',
#   'latitude': '53.338',
#   'longitude': '-6.24153'},
#  {'id': 46911590,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 57,
#   'available_bike_stands': 19,
#   'bike_stands': 23,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:49',
#   'status': 'OPEN',
#   'address': 'Grattan Street',
#   'name': 'GRATTAN STREET',
#   'latitude': '53.3396',
#   'longitude': '-6.24378'},
#  {'id': 46911542,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 58,
#   'available_bike_stands': 22,
#   'bike_stands': 40,
#   'available_bikes': 18,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:08',
#   'status': 'OPEN',
#   'address': "Sir Patrick's Dun",
#   'name': "SIR PATRICK DUN'S",
#   'latitude': '53.3392',
#   'longitude': '-6.24064'},
#  {'id': 46911561,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 59,
#   'available_bike_stands': 20,
#   'bike_stands': 20,
#   'available_bikes': 0,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:14:48',
#   'status': 'OPEN',
#   'address': 'Denmark Street Great',
#   'name': 'DENMARK STREET GREAT',
#   'latitude': '53.3556',
#   'longitude': '-6.2614'},
#  {'id': 46911538,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 60,
#   'available_bike_stands': 26,
#   'bike_stands': 30,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:19:10',
#   'status': 'OPEN',
#   'address': 'North Circular Road',
#   'name': 'NORTH CIRCULAR ROAD',
#   'latitude': '53.3596',
#   'longitude': '-6.26035'},
#  {'id': 46911531,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 61,
#   'available_bike_stands': 24,
#   'bike_stands': 25,
#   'available_bikes': 1,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:11:20',
#   'status': 'OPEN',
#   'address': 'Hardwicke Place',
#   'name': 'HARDWICKE PLACE',
#   'latitude': '53.357',
#   'longitude': '-6.26323'},
#  {'id': 46911528,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 62,
#   'available_bike_stands': 24,
#   'bike_stands': 40,
#   'available_bikes': 16,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:43',
#   'status': 'OPEN',
#   'address': 'Lime Street',
#   'name': 'LIME STREET',
#   'latitude': '53.346',
#   'longitude': '-6.24358'},
#  {'id': 46911520,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 63,
#   'available_bike_stands': 15,
#   'bike_stands': 35,
#   'available_bikes': 20,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:13:06',
#   'status': 'OPEN',
#   'address': 'Fenian Street',
#   'name': 'FENIAN STREET',
#   'latitude': '53.3414',
#   'longitude': '-6.24672'},
#  {'id': 46911583,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 64,
#   'available_bike_stands': 36,
#   'bike_stands': 40,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:13:56',
#   'status': 'OPEN',
#   'address': 'Sandwith Street',
#   'name': 'SANDWITH STREET',
#   'latitude': '53.3452',
#   'longitude': '-6.24716'},
#  {'id': 46911577,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 65,
#   'available_bike_stands': 37,
#   'bike_stands': 40,
#   'available_bikes': 3,
#   'banking': True,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:00',
#   'status': 'OPEN',
#   'address': 'Convention Centre',
#   'name': 'CONVENTION CENTRE',
#   'latitude': '53.3474',
#   'longitude': '-6.23852'},
#  {'id': 46911543,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 66,
#   'available_bike_stands': 37,
#   'bike_stands': 40,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:14:37',
#   'status': 'OPEN',
#   'address': 'New Central Bank',
#   'name': 'NEW CENTRAL BANK',
#   'latitude': '53.3471',
#   'longitude': '-6.23475'},
#  {'id': 46911525,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 67,
#   'available_bike_stands': 30,
#   'bike_stands': 40,
#   'available_bikes': 10,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:13:36',
#   'status': 'OPEN',
#   'address': 'The Point',
#   'name': 'THE POINT',
#   'latitude': '53.3469',
#   'longitude': '-6.23085'},
#  {'id': 46911510,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 68,
#   'available_bike_stands': 39,
#   'bike_stands': 40,
#   'available_bikes': 1,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:50',
#   'status': 'OPEN',
#   'address': 'Hanover Quay',
#   'name': 'HANOVER QUAY',
#   'latitude': '53.3441',
#   'longitude': '-6.23715'},
#  {'id': 46911557,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 69,
#   'available_bike_stands': 15,
#   'bike_stands': 40,
#   'available_bikes': 25,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:06',
#   'status': 'OPEN',
#   'address': 'Grand Canal Dock',
#   'name': 'GRAND CANAL DOCK',
#   'latitude': '53.3426',
#   'longitude': '-6.2387'},
#  {'id': 46911555,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 71,
#   'available_bike_stands': 27,
#   'bike_stands': 40,
#   'available_bikes': 13,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:02',
#   'status': 'OPEN',
#   'address': 'Kevin Street',
#   'name': 'KEVIN STREET',
#   'latitude': '53.3378',
#   'longitude': '-6.2677'},
#  {'id': 46911519,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 72,
#   'available_bike_stands': 16,
#   'bike_stands': 31,
#   'available_bikes': 15,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:14:11',
#   'status': 'OPEN',
#   'address': 'John Street West',
#   'name': 'JOHN STREET WEST',
#   'latitude': '53.3431',
#   'longitude': '-6.27717'},
#  {'id': 46911533,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 73,
#   'available_bike_stands': 24,
#   'bike_stands': 30,
#   'available_bikes': 6,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:10:04',
#   'status': 'OPEN',
#   'address': 'Francis Street',
#   'name': 'FRANCIS STREET',
#   'latitude': '53.3421',
#   'longitude': '-6.27523'},
#  {'id': 46911511,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 74,
#   'available_bike_stands': 0,
#   'bike_stands': 30,
#   'available_bikes': 30,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:10:19',
#   'status': 'OPEN',
#   'address': 'Oliver Bond Street',
#   'name': 'OLIVER BOND STREET',
#   'latitude': '53.3439',
#   'longitude': '-6.28053'},
#  {'id': 46911574,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 75,
#   'available_bike_stands': 18,
#   'bike_stands': 40,
#   'available_bikes': 22,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:58',
#   'status': 'OPEN',
#   'address': 'James Street',
#   'name': 'JAMES STREET',
#   'latitude': '53.3435',
#   'longitude': '-6.28741'},
#  {'id': 46911554,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 76,
#   'available_bike_stands': 26,
#   'bike_stands': 38,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:54',
#   'status': 'OPEN',
#   'address': 'Market Street South',
#   'name': 'MARKET STREET SOUTH',
#   'latitude': '53.3423',
#   'longitude': '-6.28766'},
#  {'id': 46911532,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 77,
#   'available_bike_stands': 20,
#   'bike_stands': 29,
#   'available_bikes': 9,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:05',
#   'status': 'OPEN',
#   'address': 'Wolfe Tone Street',
#   'name': 'WOLFE TONE STREET',
#   'latitude': '53.3489',
#   'longitude': '-6.26746'},
#  {'id': 46911572,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 78,
#   'available_bike_stands': 36,
#   'bike_stands': 40,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:41',
#   'status': 'OPEN',
#   'address': 'Mater Hospital',
#   'name': 'MATER HOSPITAL',
#   'latitude': '53.36',
#   'longitude': '-6.26483'},
#  {'id': 46911556,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 79,
#   'available_bike_stands': 27,
#   'bike_stands': 27,
#   'available_bikes': 0,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:09',
#   'status': 'OPEN',
#   'address': 'Eccles Street East',
#   'name': 'ECCLES STREET EAST',
#   'latitude': '53.3581',
#   'longitude': '-6.2656'},
#  {'id': 46911591,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 80,
#   'available_bike_stands': 39,
#   'bike_stands': 40,
#   'available_bikes': 1,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:48',
#   'status': 'OPEN',
#   'address': 'St James Hospital (Luas)',
#   'name': 'ST JAMES HOSPITAL (LUAS)',
#   'latitude': '53.3414',
#   'longitude': '-6.29295'},
#  {'id': 46911553,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 82,
#   'available_bike_stands': 13,
#   'bike_stands': 22,
#   'available_bikes': 9,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:12',
#   'status': 'OPEN',
#   'address': 'Mount Brown',
#   'name': 'MOUNT BROWN',
#   'latitude': '53.3416',
#   'longitude': '-6.29719'},
#  {'id': 46911599,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 83,
#   'available_bike_stands': 31,
#   'bike_stands': 40,
#   'available_bikes': 9,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:14:18',
#   'status': 'OPEN',
#   'address': 'Emmet Road',
#   'name': 'EMMET ROAD',
#   'latitude': '53.3407',
#   'longitude': '-6.30819'},
#  {'id': 46911513,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 84,
#   'available_bike_stands': 17,
#   'bike_stands': 30,
#   'available_bikes': 13,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:14:22',
#   'status': 'OPEN',
#   'address': 'Brookfield Road',
#   'name': 'BROOKFIELD ROAD',
#   'latitude': '53.339',
#   'longitude': '-6.30022'},
#  {'id': 46911585,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 85,
#   'available_bike_stands': 21,
#   'bike_stands': 35,
#   'available_bikes': 14,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:12:53',
#   'status': 'OPEN',
#   'address': 'Rothe Abbey',
#   'name': 'ROTHE ABBEY',
#   'latitude': '53.3388',
#   'longitude': '-6.30395'},
#  {'id': 46911579,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 86,
#   'available_bike_stands': 32,
#   'bike_stands': 38,
#   'available_bikes': 6,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:12:55',
#   'status': 'OPEN',
#   'address': 'Parkgate Street',
#   'name': 'PARKGATE STREET',
#   'latitude': '53.348',
#   'longitude': '-6.2918'},
#  {'id': 46911512,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 87,
#   'available_bike_stands': 30,
#   'bike_stands': 38,
#   'available_bikes': 8,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:15:10',
#   'status': 'OPEN',
#   'address': 'Collins Barracks Museum',
#   'name': 'COLLINS BARRACKS MUSEUM',
#   'latitude': '53.3475',
#   'longitude': '-6.28525'},
#  {'id': 46911602,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 88,
#   'available_bike_stands': 27,
#   'bike_stands': 30,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:19:07',
#   'status': 'OPEN',
#   'address': 'Blackhall Place',
#   'name': 'BLACKHALL PLACE',
#   'latitude': '53.3488',
#   'longitude': '-6.28164'},
#  {'id': 46911589,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 89,
#   'available_bike_stands': 37,
#   'bike_stands': 40,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:16',
#   'status': 'OPEN',
#   'address': 'Fitzwilliam Square East',
#   'name': 'FITZWILLIAM SQUARE EAST',
#   'latitude': '53.3352',
#   'longitude': '-6.2509'},
#  {'id': 46911514,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 90,
#   'available_bike_stands': 40,
#   'bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:11',
#   'status': 'OPEN',
#   'address': 'Benson Street',
#   'name': 'BENSON STREET',
#   'latitude': '53.3442',
#   'longitude': '-6.23345'},
#  {'id': 46911522,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 91,
#   'available_bike_stands': 0,
#   'bike_stands': 30,
#   'available_bikes': 30,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:55',
#   'status': 'OPEN',
#   'address': 'South Dock Road',
#   'name': 'SOUTH DOCK ROAD',
#   'latitude': '53.3418',
#   'longitude': '-6.23129'},
#  {'id': 46911600,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 92,
#   'available_bike_stands': 10,
#   'bike_stands': 40,
#   'available_bikes': 30,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:38',
#   'status': 'OPEN',
#   'address': 'Heuston Bridge (North)',
#   'name': 'HEUSTON BRIDGE (NORTH)',
#   'latitude': '53.3478',
#   'longitude': '-6.29243'},
#  {'id': 46911566,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 93,
#   'available_bike_stands': 13,
#   'bike_stands': 40,
#   'available_bikes': 27,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:30',
#   'status': 'OPEN',
#   'address': 'Heuston Station (Central)',
#   'name': 'HEUSTON STATION (CENTRAL)',
#   'latitude': '53.3466',
#   'longitude': '-6.29692'},
#  {'id': 46911563,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 94,
#   'available_bike_stands': 32,
#   'bike_stands': 40,
#   'available_bikes': 8,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:34',
#   'status': 'OPEN',
#   'address': 'Heuston Station (Car Park)',
#   'name': 'HEUSTON STATION (CAR PARK)',
#   'latitude': '53.347',
#   'longitude': '-6.2978'},
#  {'id': 46911562,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 95,
#   'available_bike_stands': 15,
#   'bike_stands': 40,
#   'available_bikes': 25,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:09:51',
#   'status': 'OPEN',
#   'address': 'Royal Hospital',
#   'name': 'ROYAL HOSPITAL',
#   'latitude': '53.3439',
#   'longitude': '-6.29706'},
#  {'id': 46911552,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 96,
#   'available_bike_stands': 24,
#   'bike_stands': 30,
#   'available_bikes': 6,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:14:02',
#   'status': 'OPEN',
#   'address': 'Kilmainham Lane',
#   'name': 'KILMAINHAM LANE',
#   'latitude': '53.3418',
#   'longitude': '-6.30509'},
#  {'id': 46911530,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 97,
#   'available_bike_stands': 14,
#   'bike_stands': 40,
#   'available_bikes': 26,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:39',
#   'status': 'OPEN',
#   'address': 'Kilmainham Gaol',
#   'name': 'KILMAINHAM GAOL',
#   'latitude': '53.3421',
#   'longitude': '-6.31002'},
#  {'id': 46911506,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 98,
#   'available_bike_stands': 17,
#   'bike_stands': 40,
#   'available_bikes': 23,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:01',
#   'status': 'OPEN',
#   'address': 'Frederick Street South',
#   'name': 'FREDERICK STREET SOUTH',
#   'latitude': '53.3415',
#   'longitude': '-6.25685'},
#  {'id': 46911523,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 99,
#   'available_bike_stands': 18,
#   'bike_stands': 30,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:13:23',
#   'status': 'OPEN',
#   'address': 'City Quay',
#   'name': 'CITY QUAY',
#   'latitude': '53.3466',
#   'longitude': '-6.24615'},
#  {'id': 46911581,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 100,
#   'available_bike_stands': 0,
#   'bike_stands': 25,
#   'available_bikes': 25,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:10:30',
#   'status': 'OPEN',
#   'address': 'Heuston Bridge (South)',
#   'name': 'HEUSTON BRIDGE (SOUTH)',
#   'latitude': '53.3471',
#   'longitude': '-6.29204'},
#  {'id': 46911545,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 101,
#   'available_bike_stands': 18,
#   'bike_stands': 30,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:11:56',
#   'status': 'OPEN',
#   'address': 'King Street North',
#   'name': 'KING STREET NORTH',
#   'latitude': '53.3503',
#   'longitude': '-6.27351'},
#  {'id': 46911539,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 102,
#   'available_bike_stands': 36,
#   'bike_stands': 40,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:35',
#   'status': 'OPEN',
#   'address': 'Western Way',
#   'name': 'WESTERN WAY',
#   'latitude': '53.3549',
#   'longitude': '-6.26942'},
#  {'id': 46911596,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 103,
#   'available_bike_stands': 39,
#   'bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:09:27',
#   'status': 'OPEN',
#   'address': 'Grangegorman Lower (South)',
#   'name': 'GRANGEGORMAN LOWER (SOUTH)',
#   'latitude': '53.3547',
#   'longitude': '-6.27868'},
#  {'id': 46911544,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 104,
#   'available_bike_stands': 33,
#   'bike_stands': 40,
#   'available_bikes': 7,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:11:22',
#   'status': 'OPEN',
#   'address': 'Grangegorman Lower (Central)',
#   'name': 'GRANGEGORMAN LOWER (CENTRAL)',
#   'latitude': '53.3552',
#   'longitude': '-6.27842'},
#  {'id': 46911564,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 105,
#   'available_bike_stands': 30,
#   'bike_stands': 36,
#   'available_bikes': 6,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:15:57',
#   'status': 'OPEN',
#   'address': 'Grangegorman Lower (North)',
#   'name': 'GRANGEGORMAN LOWER (NORTH)',
#   'latitude': '53.356',
#   'longitude': '-6.27838'},
#  {'id': 46911508,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 106,
#   'available_bike_stands': 31,
#   'bike_stands': 40,
#   'available_bikes': 9,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:19:09',
#   'status': 'OPEN',
#   'address': 'Rathdown Road',
#   'name': 'RATHDOWN ROAD',
#   'latitude': '53.3589',
#   'longitude': '-6.28034'},
#  {'id': 46911586,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 107,
#   'available_bike_stands': 30,
#   'bike_stands': 40,
#   'available_bikes': 10,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:12:09',
#   'status': 'OPEN',
#   'address': 'Charleville Road',
#   'name': 'CHARLEVILLE ROAD',
#   'latitude': '53.3592',
#   'longitude': '-6.28187'},
#  {'id': 46911496,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 108,
#   'available_bike_stands': 12,
#   'bike_stands': 35,
#   'available_bikes': 23,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:10',
#   'status': 'OPEN',
#   'address': 'Avondale Road',
#   'name': 'AVONDALE ROAD',
#   'latitude': '53.3594',
#   'longitude': '-6.27614'},
#  {'id': 46911584,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 109,
#   'available_bike_stands': 16,
#   'bike_stands': 29,
#   'available_bikes': 13,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:13:48',
#   'status': 'OPEN',
#   'address': 'Buckingham Street Lower',
#   'name': 'BUCKINGHAM STREET LOWER',
#   'latitude': '53.3533',
#   'longitude': '-6.24932'},
#  {'id': 46911569,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 110,
#   'available_bike_stands': 21,
#   'bike_stands': 40,
#   'available_bikes': 19,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:41',
#   'status': 'OPEN',
#   'address': 'Phibsborough Road',
#   'name': 'PHIBSBOROUGH ROAD',
#   'latitude': '53.3563',
#   'longitude': '-6.27372'},
#  {'id': 46911575,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 111,
#   'available_bike_stands': 33,
#   'bike_stands': 40,
#   'available_bikes': 7,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:47',
#   'status': 'OPEN',
#   'address': 'Mountjoy Square East',
#   'name': 'MOUNTJOY SQUARE EAST',
#   'latitude': '53.3567',
#   'longitude': '-6.25636'},
#  {'id': 46911509,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 112,
#   'available_bike_stands': 24,
#   'bike_stands': 30,
#   'available_bikes': 6,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:23',
#   'status': 'OPEN',
#   'address': "North Circular Road (O'Connell's)",
#   'name': "NORTH CIRCULAR ROAD (O'CONNELL'S)",
#   'latitude': '53.3578',
#   'longitude': '-6.25156'},
#  {'id': 46911521,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 113,
#   'available_bike_stands': 17,
#   'bike_stands': 40,
#   'available_bikes': 23,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:15:19',
#   'status': 'OPEN',
#   'address': 'Merrion Square South',
#   'name': 'MERRION SQUARE SOUTH',
#   'latitude': '53.3386',
#   'longitude': '-6.24861'},
#  {'id': 46911518,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 114,
#   'available_bike_stands': 40,
#   'bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:16:54',
#   'status': 'OPEN',
#   'address': 'Wilton Terrace (Park)',
#   'name': 'WILTON TERRACE (PARK)',
#   'latitude': '53.3337',
#   'longitude': '-6.24834'},
#  {'id': 46911546,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 115,
#   'available_bike_stands': 12,
#   'bike_stands': 30,
#   'available_bikes': 18,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:17:55',
#   'status': 'OPEN',
#   'address': 'Killarney Street',
#   'name': 'KILLARNEY STREET',
#   'latitude': '53.3548',
#   'longitude': '-6.24758'},
#  {'id': 46911526,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 116,
#   'available_bike_stands': 24,
#   'bike_stands': 30,
#   'available_bikes': 6,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:18:56',
#   'status': 'OPEN',
#   'address': 'Broadstone',
#   'name': 'BROADSTONE',
#   'latitude': '53.3547',
#   'longitude': '-6.27231'},
#  {'id': 46911548,
#   'harvest_time': '2022-03-01T18:20:02',
#   'station_id': 117,
#   'available_bike_stands': 15,
#   'bike_stands': 40,
#   'available_bikes': 25,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-03-01T18:19:09',
#   'status': 'OPEN',
#   'address': 'Hanover Quay East',
#   'name': 'HANOVER QUAY EAST',
#   'latitude': '53.3437',
#   'longitude': '-6.23175'}]

# %% [markdown]
# ## Request historical data

# %%
# The basic building block for the request for historical data
historic_api_url = "https://data.smartdublin.ie/dublinbikes-api/historical/?init="

# %%
# The time and date that you would like to request historical data from. Note: in YYYY-MM-DD HH:mm:SS format
date_from = "2022-01-01 00:00:00"

# %%
# Build the historical request URL by adding the desired date_from. Use urllib.parse to handle characters such
# ':' and ' ', so that we can create a valid UR
historical_request = historic_api_url + urllib.parse.quote(date_from)
print(historical_request)
# Out:
# https://data.smartdublin.ie/dublinbikes-api/historical/?init=2022-01-01%2000%3A00%3A00

# %%
# Request the data
historic_response = requests.get(historical_request)
historic_data = historic_response.json()
historic_data
# Out:
# [{'id': 45018581,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 2,
#   'available_bike_stands': 10,
#   'bike_stands': 20,
#   'available_bikes': 10,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:39',
#   'status': 'OPEN',
#   'address': 'Blessington Street',
#   'name': 'BLESSINGTON STREET',
#   'latitude': '53.3568',
#   'longitude': '-6.26814'},
#  {'id': 45018602,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 3,
#   'available_bike_stands': 19,
#   'bike_stands': 20,
#   'available_bikes': 1,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:49:57',
#   'status': 'OPEN',
#   'address': 'Bolton Street',
#   'name': 'BOLTON STREET',
#   'latitude': '53.3512',
#   'longitude': '-6.26986'},
#  {'id': 45018542,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 4,
#   'available_bike_stands': 9,
#   'bike_stands': 20,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:39',
#   'status': 'OPEN',
#   'address': 'Greek Street',
#   'name': 'GREEK STREET',
#   'latitude': '53.3469',
#   'longitude': '-6.27298'},
#  {'id': 45018537,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 5,
#   'available_bike_stands': 17,
#   'bike_stands': 40,
#   'available_bikes': 23,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:51:48',
#   'status': 'OPEN',
#   'address': 'Charlemont Street',
#   'name': 'CHARLEMONT PLACE',
#   'latitude': '53.3307',
#   'longitude': '-6.26018'},
#  {'id': 45018506,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 6,
#   'available_bike_stands': 13,
#   'bike_stands': 20,
#   'available_bikes': 7,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:59:13',
#   'status': 'OPEN',
#   'address': 'Christchurch Place',
#   'name': 'CHRISTCHURCH PLACE',
#   'latitude': '53.3434',
#   'longitude': '-6.27012'},
#  {'id': 45018545,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 7,
#   'available_bike_stands': 4,
#   'bike_stands': 29,
#   'available_bikes': 25,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:27',
#   'status': 'OPEN',
#   'address': 'High Street',
#   'name': 'HIGH STREET',
#   'latitude': '53.3436',
#   'longitude': '-6.27507'},
#  {'id': 45018557,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 8,
#   'available_bike_stands': 26,
#   'bike_stands': 30,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:51:56',
#   'status': 'OPEN',
#   'address': 'Custom House Quay',
#   'name': 'CUSTOM HOUSE QUAY',
#   'latitude': '53.3479',
#   'longitude': '-6.24805'},
#  {'id': 45018532,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 9,
#   'available_bike_stands': 21,
#   'bike_stands': 24,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:59',
#   'status': 'OPEN',
#   'address': 'Exchequer Street',
#   'name': 'EXCHEQUER STREET',
#   'latitude': '53.343',
#   'longitude': '-6.26358'},
#  {'id': 45018589,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 10,
#   'available_bike_stands': 4,
#   'bike_stands': 16,
#   'available_bikes': 12,
#   'banking': True,
#   'bonus': False,
#   'last_update': '2021-12-31T23:52:54',
#   'status': 'OPEN',
#   'address': 'Dame Street',
#   'name': 'DAME STREET',
#   'latitude': '53.344',
#   'longitude': '-6.2668'},
#  {'id': 45018523,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 11,
#   'available_bike_stands': 18,
#   'bike_stands': 30,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:53:15',
#   'status': 'OPEN',
#   'address': 'Earlsfort Terrace',
#   'name': 'EARLSFORT TERRACE',
#   'latitude': '53.3343',
#   'longitude': '-6.2585'},
#  {'id': 45018578,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 12,
#   'available_bike_stands': 2,
#   'bike_stands': 20,
#   'available_bikes': 18,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:59',
#   'status': 'OPEN',
#   'address': 'Eccles Street',
#   'name': 'ECCLES STREET',
#   'latitude': '53.3592',
#   'longitude': '-6.26978'},
#  {'id': 45018511,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 13,
#   'available_bike_stands': 21,
#   'bike_stands': 30,
#   'available_bikes': 9,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:56:52',
#   'status': 'OPEN',
#   'address': 'Fitzwilliam Square West',
#   'name': 'FITZWILLIAM SQUARE WEST',
#   'latitude': '53.3361',
#   'longitude': '-6.25282'},
#  {'id': 45018587,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 15,
#   'available_bike_stands': 11,
#   'bike_stands': 16,
#   'available_bikes': 5,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:57',
#   'status': 'OPEN',
#   'address': 'Hardwicke Street',
#   'name': 'HARDWICKE STREET',
#   'latitude': '53.3555',
#   'longitude': '-6.26442'},
#  {'id': 45018559,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 16,
#   'available_bike_stands': 9,
#   'bike_stands': 20,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:53:13',
#   'status': 'OPEN',
#   'address': 'Georges Quay',
#   'name': 'GEORGES QUAY',
#   'latitude': '53.3475',
#   'longitude': '-6.25219'},
#  {'id': 45018524,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 17,
#   'available_bike_stands': 10,
#   'bike_stands': 20,
#   'available_bikes': 10,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:53:54',
#   'status': 'OPEN',
#   'address': 'Golden Lane',
#   'name': 'GOLDEN LANE',
#   'latitude': '53.3408',
#   'longitude': '-6.26773'},
#  {'id': 45018507,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 18,
#   'available_bike_stands': 17,
#   'bike_stands': 30,
#   'available_bikes': 13,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:47',
#   'status': 'OPEN',
#   'address': 'Grantham Street',
#   'name': 'GRANTHAM STREET',
#   'latitude': '53.3341',
#   'longitude': '-6.26544'},
#  {'id': 45018544,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 19,
#   'available_bike_stands': 12,
#   'bike_stands': 30,
#   'available_bikes': 18,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:16',
#   'status': 'OPEN',
#   'address': 'Herbert Place',
#   'name': 'HERBERT PLACE',
#   'latitude': '53.3344',
#   'longitude': '-6.24557'},
#  {'id': 45018610,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 21,
#   'available_bike_stands': 28,
#   'bike_stands': 30,
#   'available_bikes': 2,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:53:31',
#   'status': 'OPEN',
#   'address': 'Leinster Street South',
#   'name': 'LEINSTER STREET SOUTH',
#   'latitude': '53.3422',
#   'longitude': '-6.25449'},
#  {'id': 45018575,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 22,
#   'available_bike_stands': 9,
#   'bike_stands': 20,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:56:37',
#   'status': 'OPEN',
#   'address': 'Townsend Street',
#   'name': 'TOWNSEND STREET',
#   'latitude': '53.3459',
#   'longitude': '-6.25461'},
#  {'id': 45018515,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 23,
#   'available_bike_stands': 23,
#   'bike_stands': 30,
#   'available_bikes': 7,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:53:03',
#   'status': 'OPEN',
#   'address': 'Custom House',
#   'name': 'CUSTOM HOUSE',
#   'latitude': '53.3483',
#   'longitude': '-6.25466'},
#  {'id': 45018591,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 24,
#   'available_bike_stands': 10,
#   'bike_stands': 20,
#   'available_bikes': 10,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:55:57',
#   'status': 'OPEN',
#   'address': 'Cathal Brugha Street',
#   'name': 'CATHAL BRUGHA STREET',
#   'latitude': '53.3521',
#   'longitude': '-6.26053'},
#  {'id': 45018566,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 25,
#   'available_bike_stands': 15,
#   'bike_stands': 30,
#   'available_bikes': 15,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:34',
#   'status': 'OPEN',
#   'address': 'Merrion Square East',
#   'name': 'MERRION SQUARE EAST',
#   'latitude': '53.3394',
#   'longitude': '-6.24655'},
#  {'id': 45018585,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 26,
#   'available_bike_stands': 10,
#   'bike_stands': 20,
#   'available_bikes': 10,
#   'banking': True,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:05',
#   'status': 'OPEN',
#   'address': 'Merrion Square West',
#   'name': 'MERRION SQUARE WEST',
#   'latitude': '53.3398',
#   'longitude': '-6.25199'},
#  {'id': 45018558,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 27,
#   'available_bike_stands': 20,
#   'bike_stands': 20,
#   'available_bikes': 0,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:04',
#   'status': 'OPEN',
#   'address': 'Molesworth Street',
#   'name': 'MOLESWORTH STREET',
#   'latitude': '53.3413',
#   'longitude': '-6.25812'},
#  {'id': 45018606,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 28,
#   'available_bike_stands': 21,
#   'bike_stands': 30,
#   'available_bikes': 9,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:53:52',
#   'status': 'OPEN',
#   'address': 'Mountjoy Square West',
#   'name': 'MOUNTJOY SQUARE WEST',
#   'latitude': '53.3563',
#   'longitude': '-6.25859'},
#  {'id': 45018604,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 29,
#   'available_bike_stands': 12,
#   'bike_stands': 29,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:51:47',
#   'status': 'OPEN',
#   'address': 'Ormond Quay Upper',
#   'name': 'ORMOND QUAY UPPER',
#   'latitude': '53.3461',
#   'longitude': '-6.268'},
#  {'id': 45018502,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 30,
#   'available_bike_stands': 18,
#   'bike_stands': 20,
#   'available_bikes': 2,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:59:39',
#   'status': 'OPEN',
#   'address': 'Parnell Square North',
#   'name': 'PARNELL SQUARE NORTH',
#   'latitude': '53.3535',
#   'longitude': '-6.26531'},
#  {'id': 45018513,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 31,
#   'available_bike_stands': 4,
#   'bike_stands': 20,
#   'available_bikes': 16,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:52:22',
#   'status': 'OPEN',
#   'address': 'Parnell Street',
#   'name': 'PARNELL STREET',
#   'latitude': '53.3509',
#   'longitude': '-6.26512'},
#  {'id': 45018508,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 32,
#   'available_bike_stands': 19,
#   'bike_stands': 30,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:51:51',
#   'status': 'OPEN',
#   'address': 'Pearse Street',
#   'name': 'PEARSE STREET',
#   'latitude': '53.3443',
#   'longitude': '-6.25043'},
#  {'id': 45018596,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 33,
#   'available_bike_stands': 1,
#   'bike_stands': 23,
#   'available_bikes': 22,
#   'banking': True,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:51',
#   'status': 'OPEN',
#   'address': "Princes Street / O'Connell Street",
#   'name': "PRINCES STREET / O'CONNELL STREET",
#   'latitude': '53.349',
#   'longitude': '-6.26031'},
#  {'id': 45018579,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 34,
#   'available_bike_stands': 17,
#   'bike_stands': 30,
#   'available_bikes': 13,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:56:27',
#   'status': 'OPEN',
#   'address': 'Portobello Harbour',
#   'name': 'PORTOBELLO HARBOUR',
#   'latitude': '53.3304',
#   'longitude': '-6.26516'},
#  {'id': 45018573,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 36,
#   'available_bike_stands': 25,
#   'bike_stands': 40,
#   'available_bikes': 14,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:08',
#   'status': 'OPEN',
#   'address': "St. Stephen's Green East",
#   'name': "ST. STEPHEN'S GREEN EAST",
#   'latitude': '53.3378',
#   'longitude': '-6.25603'},
#  {'id': 45018568,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 37,
#   'available_bike_stands': 21,
#   'bike_stands': 30,
#   'available_bikes': 9,
#   'banking': True,
#   'bonus': False,
#   'last_update': '2021-12-31T23:51:41',
#   'status': 'OPEN',
#   'address': "St. Stephen's Green South",
#   'name': "ST. STEPHEN'S GREEN SOUTH",
#   'latitude': '53.3375',
#   'longitude': '-6.26199'},
#  {'id': 45018548,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 38,
#   'available_bike_stands': 23,
#   'bike_stands': 40,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:51:26',
#   'status': 'OPEN',
#   'address': 'Talbot Street',
#   'name': 'TALBOT STREET',
#   'latitude': '53.351',
#   'longitude': '-6.25294'},
#  {'id': 45018607,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 39,
#   'available_bike_stands': 17,
#   'bike_stands': 20,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:50:45',
#   'status': 'OPEN',
#   'address': 'Wilton Terrace',
#   'name': 'WILTON TERRACE',
#   'latitude': '53.3324',
#   'longitude': '-6.25272'},
#  {'id': 45018603,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 40,
#   'available_bike_stands': 15,
#   'bike_stands': 21,
#   'available_bikes': 6,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:52:30',
#   'status': 'OPEN',
#   'address': 'Jervis Street',
#   'name': 'JERVIS STREET',
#   'latitude': '53.3483',
#   'longitude': '-6.26665'},
#  {'id': 45018601,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 41,
#   'available_bike_stands': 11,
#   'bike_stands': 20,
#   'available_bikes': 9,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:50:53',
#   'status': 'OPEN',
#   'address': 'Harcourt Terrace',
#   'name': 'HARCOURT TERRACE',
#   'latitude': '53.3328',
#   'longitude': '-6.25794'},
#  {'id': 45018501,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 42,
#   'available_bike_stands': 11,
#   'bike_stands': 30,
#   'available_bikes': 19,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:55:26',
#   'status': 'OPEN',
#   'address': 'Smithfield North',
#   'name': 'SMITHFIELD NORTH',
#   'latitude': '53.3496',
#   'longitude': '-6.2782'},
#  {'id': 45018512,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 43,
#   'available_bike_stands': 3,
#   'bike_stands': 30,
#   'available_bikes': 27,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:52:52',
#   'status': 'OPEN',
#   'address': 'Portobello Road',
#   'name': 'PORTOBELLO ROAD',
#   'latitude': '53.3301',
#   'longitude': '-6.26804'},
#  {'id': 45018597,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 44,
#   'available_bike_stands': 10,
#   'bike_stands': 30,
#   'available_bikes': 20,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:35',
#   'status': 'OPEN',
#   'address': 'Upper Sherrard Street',
#   'name': 'UPPER SHERRARD STREET',
#   'latitude': '53.3584',
#   'longitude': '-6.26064'},
#  {'id': 45018525,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 45,
#   'available_bike_stands': 16,
#   'bike_stands': 30,
#   'available_bikes': 14,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:49',
#   'status': 'OPEN',
#   'address': 'Deverell Place',
#   'name': 'DEVERELL PLACE',
#   'latitude': '53.3515',
#   'longitude': '-6.25527'},
#  {'id': 45018555,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 47,
#   'available_bike_stands': 36,
#   'bike_stands': 40,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:51:29',
#   'status': 'OPEN',
#   'address': 'Herbert Street',
#   'name': 'HERBERT STREET',
#   'latitude': '53.3357',
#   'longitude': '-6.24551'},
#  {'id': 45018510,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 48,
#   'available_bike_stands': 28,
#   'bike_stands': 40,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:50:18',
#   'status': 'OPEN',
#   'address': 'Excise Walk',
#   'name': 'EXCISE WALK',
#   'latitude': '53.3478',
#   'longitude': '-6.24424'},
#  {'id': 45018543,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 49,
#   'available_bike_stands': 17,
#   'bike_stands': 40,
#   'available_bikes': 23,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:12',
#   'status': 'OPEN',
#   'address': 'Guild Street',
#   'name': 'GUILD STREET',
#   'latitude': '53.3479',
#   'longitude': '-6.24093'},
#  {'id': 45018576,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 50,
#   'available_bike_stands': 37,
#   'bike_stands': 40,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:49',
#   'status': 'OPEN',
#   'address': "George's Lane",
#   'name': 'GEORGES LANE',
#   'latitude': '53.3502',
#   'longitude': '-6.2797'},
#  {'id': 45018567,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 51,
#   'available_bike_stands': 39,
#   'bike_stands': 40,
#   'available_bikes': 1,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:55:44',
#   'status': 'OPEN',
#   'address': 'York Street West',
#   'name': 'YORK STREET WEST',
#   'latitude': '53.3393',
#   'longitude': '-6.2647'},
#  {'id': 45018509,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 52,
#   'available_bike_stands': 32,
#   'bike_stands': 32,
#   'available_bikes': 0,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:53:32',
#   'status': 'OPEN',
#   'address': 'York Street East',
#   'name': 'YORK STREET EAST',
#   'latitude': '53.3388',
#   'longitude': '-6.262'},
#  {'id': 45018549,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 53,
#   'available_bike_stands': 30,
#   'bike_stands': 40,
#   'available_bikes': 10,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:59:36',
#   'status': 'OPEN',
#   'address': 'Newman House',
#   'name': 'NEWMAN HOUSE',
#   'latitude': '53.3371',
#   'longitude': '-6.26059'},
#  {'id': 45018503,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 54,
#   'available_bike_stands': 28,
#   'bike_stands': 33,
#   'available_bikes': 5,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:13',
#   'status': 'OPEN',
#   'address': 'Clonmel Street',
#   'name': 'CLONMEL STREET',
#   'latitude': '53.336',
#   'longitude': '-6.26298'},
#  {'id': 45018535,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 55,
#   'available_bike_stands': 13,
#   'bike_stands': 36,
#   'available_bikes': 23,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:50:18',
#   'status': 'OPEN',
#   'address': 'Hatch Street',
#   'name': 'HATCH STREET',
#   'latitude': '53.334',
#   'longitude': '-6.26071'},
#  {'id': 45018505,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 56,
#   'available_bike_stands': 32,
#   'bike_stands': 40,
#   'available_bikes': 8,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:50:27',
#   'status': 'OPEN',
#   'address': 'Mount Street Lower',
#   'name': 'MOUNT STREET LOWER',
#   'latitude': '53.338',
#   'longitude': '-6.24153'},
#  {'id': 45018599,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 57,
#   'available_bike_stands': 20,
#   'bike_stands': 23,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:52:16',
#   'status': 'OPEN',
#   'address': 'Grattan Street',
#   'name': 'GRATTAN STREET',
#   'latitude': '53.3396',
#   'longitude': '-6.24378'},
#  {'id': 45018550,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 58,
#   'available_bike_stands': 26,
#   'bike_stands': 40,
#   'available_bikes': 14,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:52:26',
#   'status': 'OPEN',
#   'address': "Sir Patrick's Dun",
#   'name': "SIR PATRICK DUN'S",
#   'latitude': '53.3392',
#   'longitude': '-6.24064'},
#  {'id': 45018569,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 59,
#   'available_bike_stands': 4,
#   'bike_stands': 20,
#   'available_bikes': 16,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:52:08',
#   'status': 'OPEN',
#   'address': 'Denmark Street Great',
#   'name': 'DENMARK STREET GREAT',
#   'latitude': '53.3556',
#   'longitude': '-6.2614'},
#  {'id': 45018546,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 60,
#   'available_bike_stands': 4,
#   'bike_stands': 30,
#   'available_bikes': 26,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:05',
#   'status': 'OPEN',
#   'address': 'North Circular Road',
#   'name': 'NORTH CIRCULAR ROAD',
#   'latitude': '53.3596',
#   'longitude': '-6.26035'},
#  {'id': 45018539,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 61,
#   'available_bike_stands': 23,
#   'bike_stands': 25,
#   'available_bikes': 2,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:53:33',
#   'status': 'OPEN',
#   'address': 'Hardwicke Place',
#   'name': 'HARDWICKE PLACE',
#   'latitude': '53.357',
#   'longitude': '-6.26323'},
#  {'id': 45018536,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 62,
#   'available_bike_stands': 39,
#   'bike_stands': 40,
#   'available_bikes': 1,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:59:07',
#   'status': 'OPEN',
#   'address': 'Lime Street',
#   'name': 'LIME STREET',
#   'latitude': '53.346',
#   'longitude': '-6.24358'},
#  {'id': 45018528,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 63,
#   'available_bike_stands': 22,
#   'bike_stands': 35,
#   'available_bikes': 13,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:59:39',
#   'status': 'OPEN',
#   'address': 'Fenian Street',
#   'name': 'FENIAN STREET',
#   'latitude': '53.3414',
#   'longitude': '-6.24672'},
#  {'id': 45018592,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 64,
#   'available_bike_stands': 27,
#   'bike_stands': 40,
#   'available_bikes': 13,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:50',
#   'status': 'OPEN',
#   'address': 'Sandwith Street',
#   'name': 'SANDWITH STREET',
#   'latitude': '53.3452',
#   'longitude': '-6.24716'},
#  {'id': 45018586,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 65,
#   'available_bike_stands': 22,
#   'bike_stands': 40,
#   'available_bikes': 18,
#   'banking': True,
#   'bonus': False,
#   'last_update': '2021-12-31T23:50:08',
#   'status': 'OPEN',
#   'address': 'Convention Centre',
#   'name': 'CONVENTION CENTRE',
#   'latitude': '53.3474',
#   'longitude': '-6.23852'},
#  {'id': 45018551,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 66,
#   'available_bike_stands': 35,
#   'bike_stands': 40,
#   'available_bikes': 5,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:50:55',
#   'status': 'OPEN',
#   'address': 'New Central Bank',
#   'name': 'NEW CENTRAL BANK',
#   'latitude': '53.3471',
#   'longitude': '-6.23475'},
#  {'id': 45018533,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 67,
#   'available_bike_stands': 17,
#   'bike_stands': 40,
#   'available_bikes': 23,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:53',
#   'status': 'OPEN',
#   'address': 'The Point',
#   'name': 'THE POINT',
#   'latitude': '53.3469',
#   'longitude': '-6.23085'},
#  {'id': 45018518,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 68,
#   'available_bike_stands': 29,
#   'bike_stands': 40,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:50:06',
#   'status': 'OPEN',
#   'address': 'Hanover Quay',
#   'name': 'HANOVER QUAY',
#   'latitude': '53.3441',
#   'longitude': '-6.23715'},
#  {'id': 45018565,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 69,
#   'available_bike_stands': 13,
#   'bike_stands': 40,
#   'available_bikes': 27,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:52:32',
#   'status': 'OPEN',
#   'address': 'Grand Canal Dock',
#   'name': 'GRAND CANAL DOCK',
#   'latitude': '53.3426',
#   'longitude': '-6.2387'},
#  {'id': 45018563,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 71,
#   'available_bike_stands': 28,
#   'bike_stands': 40,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:27',
#   'status': 'OPEN',
#   'address': 'Kevin Street',
#   'name': 'KEVIN STREET',
#   'latitude': '53.3378',
#   'longitude': '-6.2677'},
#  {'id': 45018527,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 72,
#   'available_bike_stands': 0,
#   'bike_stands': 31,
#   'available_bikes': 31,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:47',
#   'status': 'OPEN',
#   'address': 'John Street West',
#   'name': 'JOHN STREET WEST',
#   'latitude': '53.3431',
#   'longitude': '-6.27717'},
#  {'id': 45018541,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 73,
#   'available_bike_stands': 13,
#   'bike_stands': 30,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:53:44',
#   'status': 'OPEN',
#   'address': 'Francis Street',
#   'name': 'FRANCIS STREET',
#   'latitude': '53.3421',
#   'longitude': '-6.27523'},
#  {'id': 45018519,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 74,
#   'available_bike_stands': 3,
#   'bike_stands': 30,
#   'available_bikes': 27,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:55:53',
#   'status': 'OPEN',
#   'address': 'Oliver Bond Street',
#   'name': 'OLIVER BOND STREET',
#   'latitude': '53.3439',
#   'longitude': '-6.28053'},
#  {'id': 45018582,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 75,
#   'available_bike_stands': 28,
#   'bike_stands': 40,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:55:07',
#   'status': 'OPEN',
#   'address': 'James Street',
#   'name': 'JAMES STREET',
#   'latitude': '53.3435',
#   'longitude': '-6.28741'},
#  {'id': 45018562,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 76,
#   'available_bike_stands': 28,
#   'bike_stands': 38,
#   'available_bikes': 10,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:52:09',
#   'status': 'OPEN',
#   'address': 'Market Street South',
#   'name': 'MARKET STREET SOUTH',
#   'latitude': '53.3423',
#   'longitude': '-6.28766'},
#  {'id': 45018540,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 77,
#   'available_bike_stands': 15,
#   'bike_stands': 29,
#   'available_bikes': 14,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:50:48',
#   'status': 'OPEN',
#   'address': 'Wolfe Tone Street',
#   'name': 'WOLFE TONE STREET',
#   'latitude': '53.3489',
#   'longitude': '-6.26746'},
#  {'id': 45018580,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 78,
#   'available_bike_stands': 22,
#   'bike_stands': 40,
#   'available_bikes': 18,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:12',
#   'status': 'OPEN',
#   'address': 'Mater Hospital',
#   'name': 'MATER HOSPITAL',
#   'latitude': '53.36',
#   'longitude': '-6.26483'},
#  {'id': 45018564,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 79,
#   'available_bike_stands': 8,
#   'bike_stands': 27,
#   'available_bikes': 19,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:53:21',
#   'status': 'OPEN',
#   'address': 'Eccles Street East',
#   'name': 'ECCLES STREET EAST',
#   'latitude': '53.3581',
#   'longitude': '-6.2656'},
#  {'id': 45018600,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 80,
#   'available_bike_stands': 27,
#   'bike_stands': 40,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:49',
#   'status': 'OPEN',
#   'address': 'St James Hospital (Luas)',
#   'name': 'ST JAMES HOSPITAL (LUAS)',
#   'latitude': '53.3414',
#   'longitude': '-6.29295'},
#  {'id': 45018561,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 82,
#   'available_bike_stands': 9,
#   'bike_stands': 22,
#   'available_bikes': 13,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:31',
#   'status': 'OPEN',
#   'address': 'Mount Brown',
#   'name': 'MOUNT BROWN',
#   'latitude': '53.3416',
#   'longitude': '-6.29719'},
#  {'id': 45018608,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 83,
#   'available_bike_stands': 16,
#   'bike_stands': 40,
#   'available_bikes': 24,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:19',
#   'status': 'OPEN',
#   'address': 'Emmet Road',
#   'name': 'EMMET ROAD',
#   'latitude': '53.3407',
#   'longitude': '-6.30819'},
#  {'id': 45018521,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 84,
#   'available_bike_stands': 14,
#   'bike_stands': 30,
#   'available_bikes': 16,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:04',
#   'status': 'OPEN',
#   'address': 'Brookfield Road',
#   'name': 'BROOKFIELD ROAD',
#   'latitude': '53.339',
#   'longitude': '-6.30022'},
#  {'id': 45018594,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 85,
#   'available_bike_stands': 19,
#   'bike_stands': 35,
#   'available_bikes': 16,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:53:55',
#   'status': 'OPEN',
#   'address': 'Rothe Abbey',
#   'name': 'ROTHE ABBEY',
#   'latitude': '53.3388',
#   'longitude': '-6.30395'},
#  {'id': 45018588,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 86,
#   'available_bike_stands': 27,
#   'bike_stands': 38,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:33',
#   'status': 'OPEN',
#   'address': 'Parkgate Street',
#   'name': 'PARKGATE STREET',
#   'latitude': '53.348',
#   'longitude': '-6.2918'},
#  {'id': 45018520,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 87,
#   'available_bike_stands': 13,
#   'bike_stands': 38,
#   'available_bikes': 25,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:57',
#   'status': 'OPEN',
#   'address': 'Collins Barracks Museum',
#   'name': 'COLLINS BARRACKS MUSEUM',
#   'latitude': '53.3475',
#   'longitude': '-6.28525'},
#  {'id': 45018611,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 88,
#   'available_bike_stands': 13,
#   'bike_stands': 30,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:03',
#   'status': 'OPEN',
#   'address': 'Blackhall Place',
#   'name': 'BLACKHALL PLACE',
#   'latitude': '53.3488',
#   'longitude': '-6.28164'},
#  {'id': 45018598,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 89,
#   'available_bike_stands': 26,
#   'bike_stands': 40,
#   'available_bikes': 14,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:04',
#   'status': 'OPEN',
#   'address': 'Fitzwilliam Square East',
#   'name': 'FITZWILLIAM SQUARE EAST',
#   'latitude': '53.3352',
#   'longitude': '-6.2509'},
#  {'id': 45018522,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 90,
#   'available_bike_stands': 37,
#   'bike_stands': 40,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:56:38',
#   'status': 'OPEN',
#   'address': 'Benson Street',
#   'name': 'BENSON STREET',
#   'latitude': '53.3442',
#   'longitude': '-6.23345'},
#  {'id': 45018530,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 91,
#   'available_bike_stands': 12,
#   'bike_stands': 30,
#   'available_bikes': 18,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:56:21',
#   'status': 'OPEN',
#   'address': 'South Dock Road',
#   'name': 'SOUTH DOCK ROAD',
#   'latitude': '53.3418',
#   'longitude': '-6.23129'},
#  {'id': 45018609,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 92,
#   'available_bike_stands': 22,
#   'bike_stands': 40,
#   'available_bikes': 18,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:42',
#   'status': 'OPEN',
#   'address': 'Heuston Bridge (North)',
#   'name': 'HEUSTON BRIDGE (NORTH)',
#   'latitude': '53.3478',
#   'longitude': '-6.29243'},
#  {'id': 45018574,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 93,
#   'available_bike_stands': 15,
#   'bike_stands': 40,
#   'available_bikes': 25,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:53:36',
#   'status': 'OPEN',
#   'address': 'Heuston Station (Central)',
#   'name': 'HEUSTON STATION (CENTRAL)',
#   'latitude': '53.3466',
#   'longitude': '-6.29692'},
#  {'id': 45018571,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 94,
#   'available_bike_stands': 37,
#   'bike_stands': 40,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:59:12',
#   'status': 'OPEN',
#   'address': 'Heuston Station (Car Park)',
#   'name': 'HEUSTON STATION (CAR PARK)',
#   'latitude': '53.347',
#   'longitude': '-6.2978'},
#  {'id': 45018570,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 95,
#   'available_bike_stands': 28,
#   'bike_stands': 40,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:04',
#   'status': 'OPEN',
#   'address': 'Royal Hospital',
#   'name': 'ROYAL HOSPITAL',
#   'latitude': '53.3439',
#   'longitude': '-6.29706'},
#  {'id': 45018560,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 96,
#   'available_bike_stands': 13,
#   'bike_stands': 30,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:59:14',
#   'status': 'OPEN',
#   'address': 'Kilmainham Lane',
#   'name': 'KILMAINHAM LANE',
#   'latitude': '53.3418',
#   'longitude': '-6.30509'},
#  {'id': 45018538,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 97,
#   'available_bike_stands': 26,
#   'bike_stands': 40,
#   'available_bikes': 14,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:05',
#   'status': 'OPEN',
#   'address': 'Kilmainham Gaol',
#   'name': 'KILMAINHAM GAOL',
#   'latitude': '53.3421',
#   'longitude': '-6.31002'},
#  {'id': 45018514,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 98,
#   'available_bike_stands': 25,
#   'bike_stands': 40,
#   'available_bikes': 15,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:59:24',
#   'status': 'OPEN',
#   'address': 'Frederick Street South',
#   'name': 'FREDERICK STREET SOUTH',
#   'latitude': '53.3415',
#   'longitude': '-6.25685'},
#  {'id': 45018531,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 99,
#   'available_bike_stands': 27,
#   'bike_stands': 30,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:44',
#   'status': 'OPEN',
#   'address': 'City Quay',
#   'name': 'CITY QUAY',
#   'latitude': '53.3466',
#   'longitude': '-6.24615'},
#  {'id': 45018590,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 100,
#   'available_bike_stands': 8,
#   'bike_stands': 25,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:50:24',
#   'status': 'OPEN',
#   'address': 'Heuston Bridge (South)',
#   'name': 'HEUSTON BRIDGE (SOUTH)',
#   'latitude': '53.3471',
#   'longitude': '-6.29204'},
#  {'id': 45018553,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 101,
#   'available_bike_stands': 14,
#   'bike_stands': 30,
#   'available_bikes': 16,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:23',
#   'status': 'OPEN',
#   'address': 'King Street North',
#   'name': 'KING STREET NORTH',
#   'latitude': '53.3503',
#   'longitude': '-6.27351'},
#  {'id': 45018547,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 102,
#   'available_bike_stands': 18,
#   'bike_stands': 40,
#   'available_bikes': 22,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:55:29',
#   'status': 'OPEN',
#   'address': 'Western Way',
#   'name': 'WESTERN WAY',
#   'latitude': '53.3549',
#   'longitude': '-6.26942'},
#  {'id': 45018605,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 103,
#   'available_bike_stands': 32,
#   'bike_stands': 40,
#   'available_bikes': 8,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:49:49',
#   'status': 'OPEN',
#   'address': 'Grangegorman Lower (South)',
#   'name': 'GRANGEGORMAN LOWER (SOUTH)',
#   'latitude': '53.3547',
#   'longitude': '-6.27868'},
#  {'id': 45018552,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 104,
#   'available_bike_stands': 35,
#   'bike_stands': 40,
#   'available_bikes': 5,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:50:01',
#   'status': 'OPEN',
#   'address': 'Grangegorman Lower (Central)',
#   'name': 'GRANGEGORMAN LOWER (CENTRAL)',
#   'latitude': '53.3552',
#   'longitude': '-6.27842'},
#  {'id': 45018572,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 105,
#   'available_bike_stands': 22,
#   'bike_stands': 36,
#   'available_bikes': 14,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:51:19',
#   'status': 'OPEN',
#   'address': 'Grangegorman Lower (North)',
#   'name': 'GRANGEGORMAN LOWER (NORTH)',
#   'latitude': '53.356',
#   'longitude': '-6.27838'},
#  {'id': 45018516,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 106,
#   'available_bike_stands': 18,
#   'bike_stands': 40,
#   'available_bikes': 22,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:17',
#   'status': 'OPEN',
#   'address': 'Rathdown Road',
#   'name': 'RATHDOWN ROAD',
#   'latitude': '53.3589',
#   'longitude': '-6.28034'},
#  {'id': 45018595,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 107,
#   'available_bike_stands': 19,
#   'bike_stands': 40,
#   'available_bikes': 21,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:59:37',
#   'status': 'OPEN',
#   'address': 'Charleville Road',
#   'name': 'CHARLEVILLE ROAD',
#   'latitude': '53.3592',
#   'longitude': '-6.28187'},
#  {'id': 45018504,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 108,
#   'available_bike_stands': 10,
#   'bike_stands': 35,
#   'available_bikes': 25,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:59:08',
#   'status': 'OPEN',
#   'address': 'Avondale Road',
#   'name': 'AVONDALE ROAD',
#   'latitude': '53.3594',
#   'longitude': '-6.27614'},
#  {'id': 45018593,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 109,
#   'available_bike_stands': 22,
#   'bike_stands': 29,
#   'available_bikes': 7,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:56:01',
#   'status': 'OPEN',
#   'address': 'Buckingham Street Lower',
#   'name': 'BUCKINGHAM STREET LOWER',
#   'latitude': '53.3533',
#   'longitude': '-6.24932'},
#  {'id': 45018577,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 110,
#   'available_bike_stands': 33,
#   'bike_stands': 40,
#   'available_bikes': 7,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:59:28',
#   'status': 'OPEN',
#   'address': 'Phibsborough Road',
#   'name': 'PHIBSBOROUGH ROAD',
#   'latitude': '53.3563',
#   'longitude': '-6.27372'},
#  {'id': 45018584,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 111,
#   'available_bike_stands': 23,
#   'bike_stands': 40,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:53:59',
#   'status': 'OPEN',
#   'address': 'Mountjoy Square East',
#   'name': 'MOUNTJOY SQUARE EAST',
#   'latitude': '53.3567',
#   'longitude': '-6.25636'},
#  {'id': 45018517,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 112,
#   'available_bike_stands': 19,
#   'bike_stands': 30,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:39',
#   'status': 'OPEN',
#   'address': "North Circular Road (O'Connell's)",
#   'name': "NORTH CIRCULAR ROAD (O'CONNELL'S)",
#   'latitude': '53.3578',
#   'longitude': '-6.25156'},
#  {'id': 45018529,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 113,
#   'available_bike_stands': 40,
#   'bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:29',
#   'status': 'OPEN',
#   'address': 'Merrion Square South',
#   'name': 'MERRION SQUARE SOUTH',
#   'latitude': '53.3386',
#   'longitude': '-6.24861'},
#  {'id': 45018526,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 114,
#   'available_bike_stands': 28,
#   'bike_stands': 40,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:03',
#   'status': 'OPEN',
#   'address': 'Wilton Terrace (Park)',
#   'name': 'WILTON TERRACE (PARK)',
#   'latitude': '53.3337',
#   'longitude': '-6.24834'},
#  {'id': 45018554,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 115,
#   'available_bike_stands': 4,
#   'bike_stands': 30,
#   'available_bikes': 26,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:51:36',
#   'status': 'OPEN',
#   'address': 'Killarney Street',
#   'name': 'KILLARNEY STREET',
#   'latitude': '53.3548',
#   'longitude': '-6.24758'},
#  {'id': 45018534,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 116,
#   'available_bike_stands': 21,
#   'bike_stands': 30,
#   'available_bikes': 9,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:56:34',
#   'status': 'OPEN',
#   'address': 'Broadstone',
#   'name': 'BROADSTONE',
#   'latitude': '53.3547',
#   'longitude': '-6.27231'},
#  {'id': 45018556,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 117,
#   'available_bike_stands': 35,
#   'bike_stands': 40,
#   'available_bikes': 5,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:45',
#   'status': 'OPEN',
#   'address': 'Hanover Quay East',
#   'name': 'HANOVER QUAY EAST',
#   'latitude': '53.3437',
#   'longitude': '-6.23175'},
#  {'id': 45018583,
#   'harvest_time': '2022-01-01T00:00:04',
#   'station_id': 507,
#   'available_bike_stands': 0,
#   'bike_stands': 1,
#   'available_bikes': 1,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-11-18T07:11:16',
#   'status': 'OPEN',
#   'address': 'JCDecaux Ireland, 52 Oriel Street Lower, Dublin 1',
#   'name': 'ORIEL STREET TEST TERMINAL',
#   'latitude': '53.3546',
#   'longitude': '-6.24262'},
#  {'id': 45018692,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 2,
#   'available_bike_stands': 10,
#   'bike_stands': 20,
#   'available_bikes': 10,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:39',
#   'status': 'OPEN',
#   'address': 'Blessington Street',
#   'name': 'BLESSINGTON STREET',
#   'latitude': '53.3568',
#   'longitude': '-6.26814'},
#  {'id': 45018713,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 3,
#   'available_bike_stands': 19,
#   'bike_stands': 20,
#   'available_bikes': 1,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:00:03',
#   'status': 'OPEN',
#   'address': 'Bolton Street',
#   'name': 'BOLTON STREET',
#   'latitude': '53.3512',
#   'longitude': '-6.26986'},
#  {'id': 45018653,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 4,
#   'available_bike_stands': 9,
#   'bike_stands': 20,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:39',
#   'status': 'OPEN',
#   'address': 'Greek Street',
#   'name': 'GREEK STREET',
#   'latitude': '53.3469',
#   'longitude': '-6.27298'},
#  {'id': 45018648,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 5,
#   'available_bike_stands': 17,
#   'bike_stands': 40,
#   'available_bikes': 23,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:01:53',
#   'status': 'OPEN',
#   'address': 'Charlemont Street',
#   'name': 'CHARLEMONT PLACE',
#   'latitude': '53.3307',
#   'longitude': '-6.26018'},
#  {'id': 45018617,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 6,
#   'available_bike_stands': 13,
#   'bike_stands': 20,
#   'available_bikes': 7,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:59:13',
#   'status': 'OPEN',
#   'address': 'Christchurch Place',
#   'name': 'CHRISTCHURCH PLACE',
#   'latitude': '53.3434',
#   'longitude': '-6.27012'},
#  {'id': 45018656,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 7,
#   'available_bike_stands': 4,
#   'bike_stands': 29,
#   'available_bikes': 25,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:00:15',
#   'status': 'OPEN',
#   'address': 'High Street',
#   'name': 'HIGH STREET',
#   'latitude': '53.3436',
#   'longitude': '-6.27507'},
#  {'id': 45018668,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 8,
#   'available_bike_stands': 26,
#   'bike_stands': 30,
#   'available_bikes': 4,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:02:02',
#   'status': 'OPEN',
#   'address': 'Custom House Quay',
#   'name': 'CUSTOM HOUSE QUAY',
#   'latitude': '53.3479',
#   'longitude': '-6.24805'},
#  {'id': 45018643,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 9,
#   'available_bike_stands': 21,
#   'bike_stands': 24,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:59',
#   'status': 'OPEN',
#   'address': 'Exchequer Street',
#   'name': 'EXCHEQUER STREET',
#   'latitude': '53.343',
#   'longitude': '-6.26358'},
#  {'id': 45018700,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 10,
#   'available_bike_stands': 4,
#   'bike_stands': 16,
#   'available_bikes': 12,
#   'banking': True,
#   'bonus': False,
#   'last_update': '2022-01-01T00:03:01',
#   'status': 'OPEN',
#   'address': 'Dame Street',
#   'name': 'DAME STREET',
#   'latitude': '53.344',
#   'longitude': '-6.2668'},
#  {'id': 45018634,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 11,
#   'available_bike_stands': 18,
#   'bike_stands': 30,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:03:22',
#   'status': 'OPEN',
#   'address': 'Earlsfort Terrace',
#   'name': 'EARLSFORT TERRACE',
#   'latitude': '53.3343',
#   'longitude': '-6.2585'},
#  {'id': 45018689,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 12,
#   'available_bike_stands': 2,
#   'bike_stands': 20,
#   'available_bikes': 18,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:59',
#   'status': 'OPEN',
#   'address': 'Eccles Street',
#   'name': 'ECCLES STREET',
#   'latitude': '53.3592',
#   'longitude': '-6.26978'},
#  {'id': 45018622,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 13,
#   'available_bike_stands': 21,
#   'bike_stands': 30,
#   'available_bikes': 9,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:01:33',
#   'status': 'OPEN',
#   'address': 'Fitzwilliam Square West',
#   'name': 'FITZWILLIAM SQUARE WEST',
#   'latitude': '53.3361',
#   'longitude': '-6.25282'},
#  {'id': 45018698,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 15,
#   'available_bike_stands': 11,
#   'bike_stands': 16,
#   'available_bikes': 5,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:54:57',
#   'status': 'OPEN',
#   'address': 'Hardwicke Street',
#   'name': 'HARDWICKE STREET',
#   'latitude': '53.3555',
#   'longitude': '-6.26442'},
#  {'id': 45018670,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 16,
#   'available_bike_stands': 9,
#   'bike_stands': 20,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:03:19',
#   'status': 'OPEN',
#   'address': 'Georges Quay',
#   'name': 'GEORGES QUAY',
#   'latitude': '53.3475',
#   'longitude': '-6.25219'},
#  {'id': 45018635,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 17,
#   'available_bike_stands': 10,
#   'bike_stands': 20,
#   'available_bikes': 10,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:04:01',
#   'status': 'OPEN',
#   'address': 'Golden Lane',
#   'name': 'GOLDEN LANE',
#   'latitude': '53.3408',
#   'longitude': '-6.26773'},
#  {'id': 45018618,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 18,
#   'available_bike_stands': 17,
#   'bike_stands': 30,
#   'available_bikes': 13,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:58:47',
#   'status': 'OPEN',
#   'address': 'Grantham Street',
#   'name': 'GRANTHAM STREET',
#   'latitude': '53.3341',
#   'longitude': '-6.26544'},
#  {'id': 45018655,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 19,
#   'available_bike_stands': 12,
#   'bike_stands': 30,
#   'available_bikes': 18,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-12-31T23:57:16',
#   'status': 'OPEN',
#   'address': 'Herbert Place',
#   'name': 'HERBERT PLACE',
#   'latitude': '53.3344',
#   'longitude': '-6.24557'},
#  {'id': 45018721,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 21,
#   'available_bike_stands': 28,
#   'bike_stands': 30,
#   'available_bikes': 2,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:03:37',
#   'status': 'OPEN',
#   'address': 'Leinster Street South',
#   'name': 'LEINSTER STREET SOUTH',
#   'latitude': '53.3422',
#   'longitude': '-6.25449'},
#  {'id': 45018686,
#   'harvest_time': '2022-01-01T00:05:02',
#   'station_id': 22,
#   'available_bike_stands': 9,
#   'bike_stands': 20,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
# ...
#   'available_bikes': 10,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:32:33',
#   'status': 'OPEN',
#   'address': 'Market Street South',
#   'name': 'MARKET STREET SOUTH',
#   'latitude': '53.3423',
#   'longitude': '-6.28766'},
#  {'id': 45019428,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 77,
#   'available_bike_stands': 14,
#   'bike_stands': 29,
#   'available_bikes': 15,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:37:10',
#   'status': 'OPEN',
#   'address': 'Wolfe Tone Street',
#   'name': 'WOLFE TONE STREET',
#   'latitude': '53.3489',
#   'longitude': '-6.26746'},
#  {'id': 45019468,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 78,
#   'available_bike_stands': 23,
#   'bike_stands': 40,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:36:18',
#   'status': 'OPEN',
#   'address': 'Mater Hospital',
#   'name': 'MATER HOSPITAL',
#   'latitude': '53.36',
#   'longitude': '-6.26483'},
#  {'id': 45019452,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 79,
#   'available_bike_stands': 8,
#   'bike_stands': 27,
#   'available_bikes': 19,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:33:44',
#   'status': 'OPEN',
#   'address': 'Eccles Street East',
#   'name': 'ECCLES STREET EAST',
#   'latitude': '53.3581',
#   'longitude': '-6.2656'},
#  {'id': 45019488,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 80,
#   'available_bike_stands': 27,
#   'bike_stands': 40,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:38:14',
#   'status': 'OPEN',
#   'address': 'St James Hospital (Luas)',
#   'name': 'ST JAMES HOSPITAL (LUAS)',
#   'latitude': '53.3414',
#   'longitude': '-6.29295'},
#  {'id': 45019449,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 82,
#   'available_bike_stands': 9,
#   'bike_stands': 22,
#   'available_bikes': 13,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:34:55',
#   'status': 'OPEN',
#   'address': 'Mount Brown',
#   'name': 'MOUNT BROWN',
#   'latitude': '53.3416',
#   'longitude': '-6.29719'},
#  {'id': 45019496,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 83,
#   'available_bike_stands': 15,
#   'bike_stands': 40,
#   'available_bikes': 25,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:39:08',
#   'status': 'OPEN',
#   'address': 'Emmet Road',
#   'name': 'EMMET ROAD',
#   'latitude': '53.3407',
#   'longitude': '-6.30819'},
#  {'id': 45019409,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 84,
#   'available_bike_stands': 14,
#   'bike_stands': 30,
#   'available_bikes': 16,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:34:30',
#   'status': 'OPEN',
#   'address': 'Brookfield Road',
#   'name': 'BROOKFIELD ROAD',
#   'latitude': '53.339',
#   'longitude': '-6.30022'},
#  {'id': 45019482,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 85,
#   'available_bike_stands': 19,
#   'bike_stands': 35,
#   'available_bikes': 16,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:34:18',
#   'status': 'OPEN',
#   'address': 'Rothe Abbey',
#   'name': 'ROTHE ABBEY',
#   'latitude': '53.3388',
#   'longitude': '-6.30395'},
#  {'id': 45019476,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 86,
#   'available_bike_stands': 27,
#   'bike_stands': 38,
#   'available_bikes': 11,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:38:56',
#   'status': 'OPEN',
#   'address': 'Parkgate Street',
#   'name': 'PARKGATE STREET',
#   'latitude': '53.348',
#   'longitude': '-6.2918'},
#  {'id': 45019408,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 87,
#   'available_bike_stands': 13,
#   'bike_stands': 38,
#   'available_bikes': 25,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:39:23',
#   'status': 'OPEN',
#   'address': 'Collins Barracks Museum',
#   'name': 'COLLINS BARRACKS MUSEUM',
#   'latitude': '53.3475',
#   'longitude': '-6.28525'},
#  {'id': 45019499,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 88,
#   'available_bike_stands': 13,
#   'bike_stands': 30,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:37:28',
#   'status': 'OPEN',
#   'address': 'Blackhall Place',
#   'name': 'BLACKHALL PLACE',
#   'latitude': '53.3488',
#   'longitude': '-6.28164'},
#  {'id': 45019486,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 89,
#   'available_bike_stands': 26,
#   'bike_stands': 40,
#   'available_bikes': 14,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:32:18',
#   'status': 'OPEN',
#   'address': 'Fitzwilliam Square East',
#   'name': 'FITZWILLIAM SQUARE EAST',
#   'latitude': '53.3352',
#   'longitude': '-6.2509'},
#  {'id': 45019410,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 90,
#   'available_bike_stands': 37,
#   'bike_stands': 40,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:37:04',
#   'status': 'OPEN',
#   'address': 'Benson Street',
#   'name': 'BENSON STREET',
#   'latitude': '53.3442',
#   'longitude': '-6.23345'},
#  {'id': 45019418,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 91,
#   'available_bike_stands': 13,
#   'bike_stands': 30,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:34:15',
#   'status': 'OPEN',
#   'address': 'South Dock Road',
#   'name': 'SOUTH DOCK ROAD',
#   'latitude': '53.3418',
#   'longitude': '-6.23129'},
#  {'id': 45019497,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 92,
#   'available_bike_stands': 22,
#   'bike_stands': 40,
#   'available_bikes': 18,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:38:05',
#   'status': 'OPEN',
#   'address': 'Heuston Bridge (North)',
#   'name': 'HEUSTON BRIDGE (NORTH)',
#   'latitude': '53.3478',
#   'longitude': '-6.29243'},
#  {'id': 45019462,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 93,
#   'available_bike_stands': 15,
#   'bike_stands': 40,
#   'available_bikes': 25,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:30:01',
#   'status': 'OPEN',
#   'address': 'Heuston Station (Central)',
#   'name': 'HEUSTON STATION (CENTRAL)',
#   'latitude': '53.3466',
#   'longitude': '-6.29692'},
#  {'id': 45019459,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 94,
#   'available_bike_stands': 37,
#   'bike_stands': 40,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:39:36',
#   'status': 'OPEN',
#   'address': 'Heuston Station (Car Park)',
#   'name': 'HEUSTON STATION (CAR PARK)',
#   'latitude': '53.347',
#   'longitude': '-6.2978'},
#  {'id': 45019458,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 95,
#   'available_bike_stands': 28,
#   'bike_stands': 40,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:37:30',
#   'status': 'OPEN',
#   'address': 'Royal Hospital',
#   'name': 'ROYAL HOSPITAL',
#   'latitude': '53.3439',
#   'longitude': '-6.29706'},
#  {'id': 45019448,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 96,
#   'available_bike_stands': 13,
#   'bike_stands': 30,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:39:40',
#   'status': 'OPEN',
#   'address': 'Kilmainham Lane',
#   'name': 'KILMAINHAM LANE',
#   'latitude': '53.3418',
#   'longitude': '-6.30509'},
#  {'id': 45019426,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 97,
#   'available_bike_stands': 26,
#   'bike_stands': 40,
#   'available_bikes': 14,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:34:31',
#   'status': 'OPEN',
#   'address': 'Kilmainham Gaol',
#   'name': 'KILMAINHAM GAOL',
#   'latitude': '53.3421',
#   'longitude': '-6.31002'},
#  {'id': 45019402,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 98,
#   'available_bike_stands': 25,
#   'bike_stands': 40,
#   'available_bikes': 15,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:39:47',
#   'status': 'OPEN',
#   'address': 'Frederick Street South',
#   'name': 'FREDERICK STREET SOUTH',
#   'latitude': '53.3415',
#   'longitude': '-6.25685'},
#  {'id': 45019419,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 99,
#   'available_bike_stands': 27,
#   'bike_stands': 30,
#   'available_bikes': 3,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:35:07',
#   'status': 'OPEN',
#   'address': 'City Quay',
#   'name': 'CITY QUAY',
#   'latitude': '53.3466',
#   'longitude': '-6.24615'},
#  {'id': 45019478,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 100,
#   'available_bike_stands': 8,
#   'bike_stands': 25,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:30:50',
#   'status': 'OPEN',
#   'address': 'Heuston Bridge (South)',
#   'name': 'HEUSTON BRIDGE (SOUTH)',
#   'latitude': '53.3471',
#   'longitude': '-6.29204'},
#  {'id': 45019441,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 101,
#   'available_bike_stands': 13,
#   'bike_stands': 30,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:32:22',
#   'status': 'OPEN',
#   'address': 'King Street North',
#   'name': 'KING STREET NORTH',
#   'latitude': '53.3503',
#   'longitude': '-6.27351'},
#  {'id': 45019435,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 102,
#   'available_bike_stands': 18,
#   'bike_stands': 40,
#   'available_bikes': 22,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:35:52',
#   'status': 'OPEN',
#   'address': 'Western Way',
#   'name': 'WESTERN WAY',
#   'latitude': '53.3549',
#   'longitude': '-6.26942'},
#  {'id': 45019493,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 103,
#   'available_bike_stands': 32,
#   'bike_stands': 40,
#   'available_bikes': 8,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:30:12',
#   'status': 'OPEN',
#   'address': 'Grangegorman Lower (South)',
#   'name': 'GRANGEGORMAN LOWER (SOUTH)',
#   'latitude': '53.3547',
#   'longitude': '-6.27868'},
#  {'id': 45019440,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 104,
#   'available_bike_stands': 35,
#   'bike_stands': 40,
#   'available_bikes': 5,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:30:27',
#   'status': 'OPEN',
#   'address': 'Grangegorman Lower (Central)',
#   'name': 'GRANGEGORMAN LOWER (CENTRAL)',
#   'latitude': '53.3552',
#   'longitude': '-6.27842'},
#  {'id': 45019460,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 105,
#   'available_bike_stands': 22,
#   'bike_stands': 36,
#   'available_bikes': 14,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:31:44',
#   'status': 'OPEN',
#   'address': 'Grangegorman Lower (North)',
#   'name': 'GRANGEGORMAN LOWER (NORTH)',
#   'latitude': '53.356',
#   'longitude': '-6.27838'},
#  {'id': 45019404,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 106,
#   'available_bike_stands': 18,
#   'bike_stands': 40,
#   'available_bikes': 22,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:39:28',
#   'status': 'OPEN',
#   'address': 'Rathdown Road',
#   'name': 'RATHDOWN ROAD',
#   'latitude': '53.3589',
#   'longitude': '-6.28034'},
#  {'id': 45019483,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 107,
#   'available_bike_stands': 19,
#   'bike_stands': 40,
#   'available_bikes': 21,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:29:57',
#   'status': 'OPEN',
#   'address': 'Charleville Road',
#   'name': 'CHARLEVILLE ROAD',
#   'latitude': '53.3592',
#   'longitude': '-6.28187'},
#  {'id': 45019392,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 108,
#   'available_bike_stands': 10,
#   'bike_stands': 35,
#   'available_bikes': 25,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:31:55',
#   'status': 'OPEN',
#   'address': 'Avondale Road',
#   'name': 'AVONDALE ROAD',
#   'latitude': '53.3594',
#   'longitude': '-6.27614'},
#  {'id': 45019481,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 109,
#   'available_bike_stands': 22,
#   'bike_stands': 29,
#   'available_bikes': 7,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:36:24',
#   'status': 'OPEN',
#   'address': 'Buckingham Street Lower',
#   'name': 'BUCKINGHAM STREET LOWER',
#   'latitude': '53.3533',
#   'longitude': '-6.24932'},
#  {'id': 45019465,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 110,
#   'available_bike_stands': 33,
#   'bike_stands': 40,
#   'available_bikes': 7,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:29:47',
#   'status': 'OPEN',
#   'address': 'Phibsborough Road',
#   'name': 'PHIBSBOROUGH ROAD',
#   'latitude': '53.3563',
#   'longitude': '-6.27372'},
#  {'id': 45019472,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 111,
#   'available_bike_stands': 23,
#   'bike_stands': 40,
#   'available_bikes': 17,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:34:21',
#   'status': 'OPEN',
#   'address': 'Mountjoy Square East',
#   'name': 'MOUNTJOY SQUARE EAST',
#   'latitude': '53.3567',
#   'longitude': '-6.25636'},
#  {'id': 45019405,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 112,
#   'available_bike_stands': 16,
#   'bike_stands': 30,
#   'available_bikes': 14,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:35:16',
#   'status': 'OPEN',
#   'address': "North Circular Road (O'Connell's)",
#   'name': "NORTH CIRCULAR ROAD (O'CONNELL'S)",
#   'latitude': '53.3578',
#   'longitude': '-6.25156'},
#  {'id': 45019417,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 113,
#   'available_bike_stands': 40,
#   'bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:37:56',
#   'status': 'OPEN',
#   'address': 'Merrion Square South',
#   'name': 'MERRION SQUARE SOUTH',
#   'latitude': '53.3386',
#   'longitude': '-6.24861'},
#  {'id': 45019414,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 114,
#   'available_bike_stands': 28,
#   'bike_stands': 40,
#   'available_bikes': 12,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:34:26',
#   'status': 'OPEN',
#   'address': 'Wilton Terrace (Park)',
#   'name': 'WILTON TERRACE (PARK)',
#   'latitude': '53.3337',
#   'longitude': '-6.24834'},
#  {'id': 45019442,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 115,
#   'available_bike_stands': 4,
#   'bike_stands': 30,
#   'available_bikes': 26,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:32:02',
#   'status': 'OPEN',
#   'address': 'Killarney Street',
#   'name': 'KILLARNEY STREET',
#   'latitude': '53.3548',
#   'longitude': '-6.24758'},
#  {'id': 45019422,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 116,
#   'available_bike_stands': 21,
#   'bike_stands': 30,
#   'available_bikes': 9,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:36:59',
#   'status': 'OPEN',
#   'address': 'Broadstone',
#   'name': 'BROADSTONE',
#   'latitude': '53.3547',
#   'longitude': '-6.27231'},
#  {'id': 45019444,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 117,
#   'available_bike_stands': 35,
#   'bike_stands': 40,
#   'available_bikes': 5,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:31:54',
#   'status': 'OPEN',
#   'address': 'Hanover Quay East',
#   'name': 'HANOVER QUAY EAST',
#   'latitude': '53.3437',
#   'longitude': '-6.23175'},
#  {'id': 45019471,
#   'harvest_time': '2022-01-01T00:40:02',
#   'station_id': 507,
#   'available_bike_stands': 0,
#   'bike_stands': 1,
#   'available_bikes': 1,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2021-11-18T07:11:16',
#   'status': 'OPEN',
#   'address': 'JCDecaux Ireland, 52 Oriel Street Lower, Dublin 1',
#   'name': 'ORIEL STREET TEST TERMINAL',
#   'latitude': '53.3546',
#   'longitude': '-6.24262'},
#  {'id': 45019580,
#   'harvest_time': '2022-01-01T00:45:02',
#   'station_id': 2,
#   'available_bike_stands': 11,
#   'bike_stands': 20,
#   'available_bikes': 9,
#   'banking': False,
#   'bonus': False,
#   'last_update': '2022-01-01T00:37:32',
#   'status': 'OPEN',
#   'address': 'Blessington Street',
#   'name': 'BLESSINGTON STREET',
#   'latitude': '53.3568',
#   'longitude': '-6.26814'},
#  ...]

# %%
# historic_data is in the form of a list of json. Conver to a dataframe
historic_df = pd.DataFrame.from_records(historic_data)
historic_df.head()
# Out:
#          id         harvest_time  station_id  available_bike_stands  \
# 0  45018581  2022-01-01T00:00:04           2                     10
# 1  45018602  2022-01-01T00:00:04           3                     19
# 2  45018542  2022-01-01T00:00:04           4                      9
# 3  45018537  2022-01-01T00:00:04           5                     17
# 4  45018506  2022-01-01T00:00:04           6                     13
#
#    bike_stands  available_bikes  banking  bonus          last_update status  \
# 0           20               10    False  False  2021-12-31T23:57:39   OPEN
# 1           20                1    False  False  2021-12-31T23:49:57   OPEN
# 2           20               11    False  False  2021-12-31T23:58:39   OPEN
# 3           40               23    False  False  2021-12-31T23:51:48   OPEN
# 4           20                7    False  False  2021-12-31T23:59:13   OPEN
#
#               address                name latitude longitude
# 0  Blessington Street  BLESSINGTON STREET  53.3568  -6.26814
# 1       Bolton Street       BOLTON STREET  53.3512  -6.26986
# 2        Greek Street        GREEK STREET  53.3469  -6.27298
# 3   Charlemont Street    CHARLEMONT PLACE  53.3307  -6.26018
# 4  Christchurch Place  CHRISTCHURCH PLACE  53.3434  -6.27012
